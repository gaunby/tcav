# %%
# %load_ext autoreload
# %autoreload 2

# %%
import tcav.utils_plot as utils_plot 
import os 
import tensorflow as tf
import pickle
# Out:
# 2022-09-20 16:30:22.420310: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
start = [0,5]
end = [4,14]
result = []

for i, j in zip(start, end):
    with open(f'result_random500_{i}_to_{j}.pkl', 'rb') as handle:
        load_pickle = pickle.load(handle)
    result.extend(load_pickle)

# %%
num_random = end[-1] + 1
utils_plot.plot_results(result, num_random_exp=num_random, plot_hist = False)
# Out:
# Class = zebra
#   Concept = dotted
# >>> Number of TCAV concept observations <<<
#  15
# >>> Number of TCAV random observations <<<
#  110
#     Bottleneck = mixed3a. TCAV Score = 0.33 (+- 0.07), random was 0.50 (+- 0.11). p-val = 0.000 (significant)
#   Concept = striped
#     Bottleneck = mixed3a. TCAV Score = 0.54 (+- 0.06), random was 0.50 (+- 0.11). p-val = 0.274 (not significant)
#   Concept = zigzagged
#     Bottleneck = mixed3a. TCAV Score = 0.41 (+- 0.06), random was 0.50 (+- 0.11). p-val = 0.001 (significant)
# {'mixed3a': {'bn_vals': [0.32882882882882886, 0.01, 0.4108108108108109], 'bn_stds': [0.07246514433221696, 0, 0.05534494613840601], 'significant': [True, False, True]}}
